# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip "/content/drive/MyDrive/manifest-1786753014866.zip" -d "/content/drive/MyDrive/"
# Out:
# Archive:  /content/drive/MyDrive/manifest-1786753014866.zip
# replace /content/drive/MyDrive/__MACOSX/._manifest-1786753014866? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace /content/drive/MyDrive/__MACOSX/manifest-1786753014866/._LIDC-IDRI? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import os

# %%
colab_path="/content/drive/MyDrive/manifest-1786753014866/LIDC-IDRI"

# %%
with open('/root/.pylidcrc','w') as f:
  f.write("[dicom]\n")
  f.write(f"path={colab_path}\n")

# %%
print("Config file created successfully!")
# Out:
# Config file created successfully!

# %%
# !pip install pylidc
# Out:
# Collecting pylidc
#   Downloading pylidc-0.2.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: sqlalchemy>=1.1.5 in /usr/local/lib/python3.12/dist-packages (from pylidc) (2.0.51)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from pylidc) (2.0.2)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.12/dist-packages (from pylidc) (1.16.3)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pylidc) (3.10.0)
# Collecting pydicom>=1.0.0 (from pylidc)
#   Downloading pydicom-3.0.2-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: scikit-image>=0.13 in /usr/local/lib/python3.12/dist-packages (from pylidc) (0.25.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pylidc) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pylidc) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pylidc) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pylidc) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pylidc) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pylidc) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pylidc) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pylidc) (2.9.0.post0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.13->pylidc) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.13->pylidc) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.13->pylidc) (2026.4.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.13->pylidc) (0.5)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.1.5->pylidc) (3.5.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.1.5->pylidc) (4.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->pylidc) (1.17.0)
# Downloading pylidc-0.2.3-py2.py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 62.5 MB/s eta 0:00:00
# Downloading pydicom-3.0.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 78.4 MB/s eta 0:00:00
# Installing collected packages: pydicom, pylidc
# Successfully installed pydicom-3.0.2 pylidc-0.2.3

# %%
import pylidc as pl
import matplotlib.pyplot as plt

# %% [markdown]
# #1. QUERY THE DATABSE FOR FIRST SCAN

# %%
scan = pl.query(pl.Scan).first()
print(f"Loaded Patient ID: {scan.patient_id}")
# Out:
# Loaded Patient ID: LIDC-IDRI-0078

# %% [markdown]
# # 2. CLUSTER ANNOTATIONS(GROUPING THE DOCTOR'S DRAWINGS)

# %%
import numpy as np

# Compatibility fix for older packages using np.int
np.int = int

nodules = scan.cluster_annotations()
print(f"Found {len(nodules)} distinct nodules in this scan.")
# Out:
# Found 4 distinct nodules in this scan.

# %%
# 3. Grab the first annotation of the first nodule

# %%
annotation = nodules[0][0]

print(f"Malignancy rating (1-5): {annotation.malignancy}")
print(f"Nodule Diameter: {annotation.diameter:.2f} mm")
# Out:
# Malignancy rating (1-5): 3
# Nodule Diameter: 19.50 mm

# %% [markdown]
# # 4. Get the 3D numpy array of the nodule mask and the CT image bounding box

# %%
annotation = nodules[0][0]
vol, mask = annotation.feature_size()
bbox = annotation.bbox()
ct_pixels = scan.to_volume()
print("Volume:", vol)
print("Bounding box:", bbox)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1653/2019371302.py in <cell line: 0>()
#       1 annotation = nodules[0][0]
# ----> 2 vol, mask = annotation.feature_size()
#       3 bbox = annotation.bbox()
#       4 ct_pixels = scan.to_volume()
#       5 print("Volume:", vol)
#
# AttributeError: 'Annotation' object has no attribute 'feature_size'

# %% [markdown]
# #5. FIND THE MIDDLE SLICE OF THE 3D NODULE TO DISPLAY

# %%
mid_slice = ct_pixels.shape[2]

# %% [markdown]
# #6. Plot the original CT and the mask overlay side by side

# %%
fig, ax = plt.subplots(1,2,figsize=(12,6))

# %%
ax[0].imshow(ct_pixels[:, :, mid_slice], cmap='gray')
ax[0].set_title("Raw CT Scan Slice")
ax[0].axis('off')

# %%
ax[1].imshow(ct_pixels[:, :, mid_slice], cmap='gray')
ax[1].imshow(mask[:, :, mid_slice], cmap='Reds', alpha=0.5) # Overlay in red
ax[1].set_title("Nodule Mask Overlay")
ax[1].axis('off')

# %%
plt.tight_layout()
plt.show()
