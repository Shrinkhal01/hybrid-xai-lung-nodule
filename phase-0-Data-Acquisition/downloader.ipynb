# %%
# !pip install --upgrade -q tcia_utils
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.3/77.3 MB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 64.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 77.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 86.6 MB/s eta 0:00:00

# %%
import sys
import os
from google.colab import drive
from tcia_utils import nbia

# Mount your Google Drive
drive.mount('/content/drive')

# Define your target path in Google Drive
destination_path = "/content/drive/MyDrive/Lung_Nodule_Project/raw_data"
os.makedirs(destination_path, exist_ok=True)

print("Fetching series list for LIDC-IDRI collection...")
series_data = nbia.getSeries(collection="LIDC-IDRI", modality="CT")

print(f"Total series found: {len(series_data)}")
print(f"Downloading directly to Google Drive: {destination_path}")

# Correct parameter name uses lowercase 'd': series_data
nbia.downloadSeries(
    series_data=series_data,
    path=destination_path
)

print("Download complete! All data is securely stored in your Google Drive.")
# Out:
# Mounted at /content/drive
# Fetching series list for LIDC-IDRI collection...
# WARNING:tcia_utils.nbia:Series 1.3.6.1.4.1.14519.5.2.1.6279.6001.179049373636438705059720603192 already downloaded and unzipped.
# WARNING:tcia_utils.nbia:Series 1.3.6.1.4.1.14519.5.2.1.6279.6001.129007566048223160327836686225 already downloaded and unzipped.
# WARNING:tcia_utils.nbia:Series 1.3.6.1.4.1.14519.5.2.1.6279.6001.272348349298439120568330857680 already downloaded and unzipped.
# WARNING:tcia_utils.nbia:Series 1.3.6.1.4.1.14519.5.2.1.6279.6001.174907798609768549012640380786 already downloaded and unzipped.
# WARNING:tcia_utils.nbia:Series 1.3.6.1.4.1.14519.5.2.1.6279.6001.882070241245008756731854510592 already downloaded and unzipped.
# WARNING:tcia_utils.nbia:Series 1.3.6.1.4.1.14519.5.2.1.6279.6001.188265424231150847356515802868 already downloaded and unzipped.
# WARNING:tcia_utils.nbia:Series 1.3.6.1.4.1.14519.5.2.1.6279.6001.183843376225716802567192412456 already downloaded and unzipped.
# ...
